# %%
import importlib
importlib.reload(dry)

import numpy as np
activity_fractions=np.linspace(0, 1, 6)
for activity_fraction in activity_fractions:
        dry.run_simulation(10000, 
                            0.1,  
                            0.0001,
                            5, 
                            0.1, 
                            1,
                            activity_fraction
                            )
        dry.analyze_seperate_profiles('trajectory.gsd', 1000, activity_fraction)
# Out:
# Setting up simulation...
# Simulation completed!
# Setting up simulation...
# Simulation completed!
# Setting up simulation...
# Simulation completed!
# Setting up simulation...
# Simulation completed!
# Setting up simulation...
# Simulation completed!
# Setting up simulation...
# Simulation completed!
